# %% [markdown]
# # 📊 Análise Exploratória Inicial - Breast Cancer Dataset
# Este notebook tem como objetivo carregar, visualizar e entender os dados utilizados para o diagnóstico de câncer de mama.

# %% [markdown]
# ## ✅ Etapa 1: Importação das bibliotecas
# Essas bibliotecas serão usadas para manipular dados e criar gráficos.

# %%
import pandas as pd  # Manipulação de dados
import numpy as np  # Cálculos numéricos
import matplotlib.pyplot as plt  # Gráficos simples
import seaborn as sns  # Gráficos bonitos e avançados

# Ativar visualização dos gráficos direto no notebook
# %matplotlib inline

# %% [markdown]
# ## 📂 Etapa 2: Carregando o dataset
# Vamos carregar o arquivo `data.csv` que deve estar na pasta `../data/`.

# %%
df = pd.read_csv('../data/breast_cancer.csv')
df.head()  # Mostra as 5 primeiras linhas
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## 🔍 Etapa 3: Explorando a estrutura da base de dados

# %%
df.info()  # Informações gerais sobre as colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()  # Estatísticas descritivas
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.isnull().sum()  # Verifica se há valores ausentes
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# ## 📊 Etapa 4: Visualização dos dados

# %%
sns.countplot(x='diagnosis', data=df)
plt.title('Distribuição das Classes')
# Out:
# Text(0.5, 1.0, 'Distribuição das Classes')

# %%
df.drop(['id', 'diagnosis', 'Unnamed: 32'], axis=1).hist(bins=15, figsize=(15,10))
plt.tight_layout()

# %%
# Criar uma nova versão do dataframe só com colunas numéricas
df_numerico = df.drop(['id', 'diagnosis'], axis=1)

plt.figure(figsize=(12,10))
sns.heatmap(df_numerico.corr(), cmap='coolwarm')
plt.title('Correlação entre variáveis')
# Out:
# Text(0.5, 1.0, 'Correlação entre variáveis')

# %%
sns.boxplot(x='diagnosis', y='radius_mean', data=df)
# Out:
# <Axes: xlabel='diagnosis', ylabel='radius_mean'>

# %% [markdown]
# ## 🧾 Etapa 5: Anotações e conclusões
# - A variável `radius_mean` mostra boa separação entre as classes.
# - A coluna `id` será descartada.
# - Não há valores nulos.
# - Há variáveis com alta correlação que devem ser consideradas no pré-processamento.
